# %% [markdown]
# # Pie Chart
#
# A pie chart is a circular graph that is divided into slices to illustrate numerical proportions. Each slice represents a category's proportion of the whole.
#
# ### Example: Simple Pie Chart
#
# In this notebook, we will create a pie chart using sample data.

# %% [markdown]
# ### Importing libraries

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Creating Data

# %%
sizes = [35, 5, 55, 65, 90]
labels = ['X', 'Y', 'Z', 'T', 'M']
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'purple']

# %% [markdown]
# ### Pie Chart

# %%
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=130)
plt.title('Simple Pie Chart')
# Out:
# Text(0.5, 1.0, 'Simple Pie Chart')
