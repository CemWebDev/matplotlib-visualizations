# %% [markdown]
# # Histogram
#
# A histogram is a type of bar chart represents the distribution of a dataset. It groups data into bins or intervals and displays the frequency (count) of data points within each bin.
#
# ### Example: Simple Histogram
#
# In this notebook, we will create a simple histogram using sample data.
# ### Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Generate Random Data

# %%
data = np.random.randn(1000)

# %% [markdown]
# ### Create Histogram

# %%
plt.hist(data, bins=40, alpha=0.9, color='r')
plt.title('Simple Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
