# %% [markdown]
# # Line plots with Matplotlib
#
# In this notebook, we will create a simple line plot using Matplotlib
# ### 1. Importing Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 1. data for x and y axes

# %%
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# %% [markdown]
# ### 1. create a line plot and add title and labels(optional)

# %%
plt.plot(x, y)
plt.title('Simple Line Plot')
plt.xlabel('X axis')
plt.ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')
